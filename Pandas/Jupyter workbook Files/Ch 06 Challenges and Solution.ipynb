# %%
import pandas as pd

# %%
oo=pd.read_csv('/Users/dibyajyoti.nayak/Documents/Technical_Stuff/Pandas/data_set/SummerOlympic.csv',skiprows=4)

# %%
import matplotlib as plt

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# 1.Plot the total number of medals awarded at each of olympic games throughout history

# %%
oo.Edition.value_counts().sort_index().plot(kind='bar');

# %% [markdown]
# 2. Which countries did not win a medal in 2008 Olympics ? How many countries were there?

# %%
lo = oo[oo.Edition == 2008]
lo
# Out:
#           City  Edition      Sport       Discipline                Athlete  \
# 27174  Beijing     2008   Aquatics           Diving         GALPERIN, Gleb
# 27175  Beijing     2008   Aquatics           Diving       MITCHAM, Matthew
# 27176  Beijing     2008   Aquatics           Diving            ZHOU, Luxin
# 27177  Beijing     2008   Aquatics           Diving              WANG, Xin
# 27178  Beijing     2008   Aquatics           Diving           CHEN, Ruolin
# 27179  Beijing     2008   Aquatics           Diving        HEYMANS, Emilie
# 27180  Beijing     2008   Aquatics           Diving               QIN, Kai
# 27181  Beijing     2008   Aquatics           Diving              HE, Chong
# 27182  Beijing     2008   Aquatics           Diving    DESPATIE, Alexandre
# 27183  Beijing     2008   Aquatics           Diving             WU, Minxia
# 27184  Beijing     2008   Aquatics           Diving          GUO, Jingjing
# ...

# %%
oo1=pd.read_csv('/Users/dibyajyoti.nayak/Documents/Technical_Stuff/Pandas/data_set/SummerOlympicCOUNTRYCODES.csv')
oo1.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
oo1[oo1['Country'] != oo1['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
oo1.set_index('Int Olympic Committee code',inplace=True)

# %%
oo1.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medal_2008=lo.NOC.value_counts()
medal_2008
# Out:
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# KOR     78
# GBR     77
# FRA     76
# BRA     75
# ESP     71
# NED     62
# ARG     51
# JPN     51
# CUB     47
# ITA     42
# CAN     34
# UKR     31
# BLR     30
# HUN     27
# NGR     24
# NOR     22
# ROU     22
# POL     20
# DEN     18
# JAM     17
# SRB     15
# ISL     14
# KEN     14
# NZL     14
# KAZ     13
#       ...
# IRL      3
# IND      3
# AUT      3
# SIN      3
# EST      3
# LAT      3
# IRI      2
# DOM      2
# POR      2
# MAR      2
# TJK      2
# ALG      2
# COL      2
# KGZ      2
# MRI      1
# ECU      1
# TOG      1
# MDA      1
# RSA      1
# PAN      1
# TUN      1
# CHI      1
# MAS      1
# VEN      1
# AFG      1
# ISR      1
# VIE      1
# SUD      1
# EGY      1
# CMR      1
# Name: NOC, Length: 86, dtype: int64

# %%
oo1['medal_2008'] = medal_2008
oo1.head()
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
#
#                             medal_2008
# Int Olympic Committee code
# AFG                                1.0
# ALB                                NaN
# ALG                                2.0
# ASA                                NaN
# AND                                NaN

# %%
oo1[oo1.medal_2008.isnull()]
# Out:
#                                                      Country ISO code  \
# Int Olympic Committee code
# ALB                                                  Albania       AL
# ASA                                          American Samoa*       AS
# AND                                                  Andorra       AD
# ANG                                                   Angola       AO
# ANT                                      Antigua and Barbuda       AG
# ARU                                                   Aruba*       AW
# BRN                                                  Bahrain       BH
# BAN                                               Bangladesh       BD
# BAR                                                 Barbados       BB
# BIZ                                                   Belize       BZ
# BER                                                 Bermuda*       BM
# BEN                                                    Benin       BJ
# ...
